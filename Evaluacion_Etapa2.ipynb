# %% [markdown]
# <a href="https://colab.research.google.com/github/FerHdez24/Evaluacion/blob/main/Evaluacion_Etapa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
España = pd.read_csv('Girona_España_clean.csv')
# Out:
# <ipython-input-199-c1f50e0b305c>:1: DtypeWarning: Columns (0,1,3,9,25,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   España = pd.read_csv('Girona_España_clean.csv')

# %%
DF= pd.read_csv('DF_México_clean.csv')
# Out:
# <ipython-input-200-11cdd9a216c1>:1: DtypeWarning: Columns (1,3,9,25,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   DF= pd.read_csv('DF_México_clean.csv')

# %%
California= pd.read_csv('California_EUA_clean.csv')

# %% [markdown]
# # **ETAPA 2: Extracción  de DATOS**

# %% [markdown]
# Obtener los registros que cumplan las siguientes condiciones para cada dataframe:

# %% [markdown]
# ###**a) host_acceptance_rate> 50%**

# %%
Fa1 = España.loc[España['host_acceptance_rate'] >= .50]
Fa1
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 2              2               1212820
# 3              3                751638
# 5              5                751997
# 6              6                752035
# ...          ...                   ...
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19653      19652  858000000000000000.0
# 19654      19653  858000000000000000.0
# 19655      19654  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 2                 https://www.airbnb.com/rooms/1212820       2.02303E+13
# 3                  https://www.airbnb.com/rooms/751638       2.02303E+13
# 5                  https://www.airbnb.com/rooms/751997       2.02303E+13
# 6                  https://www.airbnb.com/rooms/752035       2.02303E+13
# ...

# %%
Fa1.to_csv("Fa1.csv")
from google.colab import files 
files.download("Fa1.csv")

# %%
Fa2 = DF.loc[DF['host_acceptance_rate'] >= .50]
Fa2
# Out:
#        Unnamed: 0                    id  \
# 2             2.0                696037
# 4             4.0                 44616
# 5             5.0               2075738
# 6             6.0                 56074
# 7             7.0                 61792
# ...           ...                   ...
# 24219     24218.0  854000000000000000.0
# 24220     24219.0  854000000000000000.0
# 24222     24221.0  854000000000000000.0
# 24223     24222.0  854000000000000000.0
# 24224     24223.0  854000000000000000.0
#
#                                            listing_url         scrape_id  \
# 2                  https://www.airbnb.com/rooms/696037          2.02E+13
# 4                   https://www.airbnb.com/rooms/44616          2.02E+13
# 5                 https://www.airbnb.com/rooms/2075738          2.02E+13
# 6                   https://www.airbnb.com/rooms/56074          2.02E+13
# 7                   https://www.airbnb.com/rooms/61792          2.02E+13
# ...

# %%
Fa2.to_csv("Fa2.csv")
from google.colab import files 
files.download("Fa2.csv")

# %%
Fa3 = California.loc[California['host_acceptance_rate'] >= .50]
Fa3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 0              0                  1.00                    1  37.770280
# 1              1                  0.71                    2  37.744740
# 2              2                  0.73                   13  37.765550
# 4              4                  0.90                    2  37.760300
# 5              5                  0.95                    1  37.784400
# ...          ...                   ...                  ...        ...
# 6927        6927                  0.98                   32  37.788619
# 6929        6929                  0.97                   67  37.725231
# 6930        6930                  1.00                    6  37.753771
# 6931        6931                  1.00                    9  37.791994
# 6934        6934                  0.50                    3  37.738325
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Fa3.to_csv("Fa3.csv")
from google.colab import files 
files.download("Fa3.csv")

# %% [markdown]
# ### **b) Sólo los registros con categoría “superhost”**

# %%
Fb1 = España.loc[España['host_is_superhost'] == 't']
Fb1
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 8              8                 45400
# 10            10                753604
# 21            21                106704
# 23            23                766763
# ...          ...                   ...
# 19598      19597  857000000000000000.0
# 19602      19601  856000000000000000.0
# 19618      19617  857000000000000000.0
# 19629      19628  858000000000000000.0
# 19652      19651  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 8                   https://www.airbnb.com/rooms/45400       2.02303E+13
# 10                 https://www.airbnb.com/rooms/753604       2.02303E+13
# 21                 https://www.airbnb.com/rooms/106704       2.02303E+13
# 23                 https://www.airbnb.com/rooms/766763       2.02303E+13
# ...

# %%
Fb1.to_csv("Fb1.csv")
from google.colab import files 
files.download("Fb1.csv")

# %%
Fb2 = DF.loc[DF['host_is_superhost'] == 't']
Fb2
# Out:
#        Unnamed: 0                    id  \
# 2             2.0                696037
# 6             6.0                 56074
# 7             7.0                 61792
# 8             8.0                704779
# 9             9.0                728372
# ...           ...                   ...
# 24172     24171.0  856000000000000000.0
# 24180     24179.0  856000000000000000.0
# 24192     24191.0  856000000000000000.0
# 24204     24203.0  857000000000000000.0
# 24223     24222.0  854000000000000000.0
#
#                                            listing_url         scrape_id  \
# 2                  https://www.airbnb.com/rooms/696037          2.02E+13
# 6                   https://www.airbnb.com/rooms/56074          2.02E+13
# 7                   https://www.airbnb.com/rooms/61792          2.02E+13
# 8                  https://www.airbnb.com/rooms/704779          2.02E+13
# 9                  https://www.airbnb.com/rooms/728372          2.02E+13
# ...

# %%
Fb2.to_csv("Fb2.csv")
from google.colab import files 
files.download("Fb2.csv")

# %%
Fb3 = California.loc[California['host_is_superhost'] == 't']
Fb3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 0              0                  1.00                    1  37.770280
# 4              4                  0.90                    2  37.760300
# 7              7                  1.00                    2  37.717500
# 8              8                  0.61                    2  37.771960
# 9              9                  0.84                    2  37.785460
# ...          ...                   ...                  ...        ...
# 6913        6913                  1.00                    2  37.719700
# 6918        6918                  1.00                   23  37.767920
# 6919        6919                  0.94                   10  37.803929
# 6923        6923                  1.00                    3  37.784690
# 6929        6929                  0.97                   67  37.725231
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Fb3.to_csv("Fb3.csv")
from google.colab import files 
files.download("Fb3.csv")

# %% [markdown]
# ### **c) Los registros que no hallan verificado identidad “ not identity_verified”**

# %%
Fc1 = España.loc[España['host_identity_verified'] == 'f']
Fc1
# Out:
#       Unnamed: 0                    id  \
# 2              2               1212820
# 7              7               1215790
# 9              9               1222762
# 30            30                784892
# 33            33               1242933
# ...          ...                   ...
# 19554      19553  856000000000000000.0
# 19561      19560  856000000000000000.0
# 19562      19561  856000000000000000.0
# 19612      19611  857000000000000000.0
# 19613      19612  857000000000000000.0
#
#                                            listing_url         scrape_id  \
# 2                 https://www.airbnb.com/rooms/1212820       2.02303E+13
# 7                 https://www.airbnb.com/rooms/1215790       2.02303E+13
# 9                 https://www.airbnb.com/rooms/1222762       2.02303E+13
# 30                 https://www.airbnb.com/rooms/784892       2.02303E+13
# 33                https://www.airbnb.com/rooms/1242933       2.02303E+13
# ...

# %%
Fc1.to_csv("Fc1.csv")
from google.colab import files 
files.download("Fc1.csv")

# %%
Fc2 = DF.loc[DF['host_identity_verified'] == 'f']
Fc2
# Out:
#        Unnamed: 0                    id  \
# 0             0.0               2056638
# 21           21.0                131610
# 61           61.0                276504
# 68           68.0                291804
# 70           70.0                298873
# ...           ...                   ...
# 23696     23695.0  842000000000000000.0
# 23874     23873.0  849000000000000000.0
# 23966     23965.0  849000000000000000.0
# 23967     23966.0  849000000000000000.0
# 23973     23972.0  849000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                 https://www.airbnb.com/rooms/2056638          2.02E+13
# 21                 https://www.airbnb.com/rooms/131610          2.02E+13
# 61                 https://www.airbnb.com/rooms/276504          2.02E+13
# 68                 https://www.airbnb.com/rooms/291804          2.02E+13
# 70                 https://www.airbnb.com/rooms/298873          2.02E+13
# ...

# %%
Fc2.to_csv("Fc2.csv")
from google.colab import files 
files.download("Fc2.csv")

# %%
Fc3 = California.loc[California['host_identity_verified'] == 'f']
Fc3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 6              6                  0.67                    1  37.747660
# 28            28                  0.60                    1  37.749160
# 38            38                  0.00                    1  37.751170
# 39            39                  1.00                    1  37.803560
# 71            71                  0.95                    5  37.792780
# ...          ...                   ...                  ...        ...
# 6885        6885                  0.98                   24  37.800850
# 6905        6905                  1.00                    2  37.731587
# 6931        6931                  1.00                    9  37.791994
# 6932        6932                  0.00                    1  37.763060
# 6933        6933                  0.00                    1  37.777633
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Fc3.to_csv("Fc3.csv")
from google.colab import files 
files.download("Fc3.csv")

# %% [markdown]
# ### **d) Los registro cuyo property_type = “Private room” y “Hotel room”**

# %%
Fd1 = España.loc[España['property_type'] == "Private room"]
Fd1
# Out:
#       Unnamed: 0                    id  \
# 356          356               3054347
# 2485        2484              14613107
# 3135        3134              17117682
# 7839        7838              32997174
# 16666      16665  658000000000000000.0
# 17058      17057  687000000000000000.0
# 19023      19022  841000000000000000.0
#
#                                            listing_url         scrape_id  \
# 356               https://www.airbnb.com/rooms/3054347       2.02303E+13
# 2485             https://www.airbnb.com/rooms/14613107       2.02303E+13
# 3135             https://www.airbnb.com/rooms/17117682       2.02303E+13
# 7839             https://www.airbnb.com/rooms/32997174       2.02303E+13
# 16666  https://www.airbnb.com/rooms/658304684608776381  20230300000000.0
# 17058  https://www.airbnb.com/rooms/686737674628035786  20230300000000.0
# 19023  https://www.airbnb.com/rooms/841208789516756655  20230300000000.0
#
#       last_scraped           source  \
# ...

# %%
Fd1.to_csv("Fd1.csv")
from google.colab import files 
files.download("Fd1.csv")

# %%
Fd2 = DF.loc[DF['property_type'] == "Private room"]
Fd2
# Out:
#        Unnamed: 0                    id  \
# 21           21.0                131610
# 1062       1062.0              12271259
# 2670       2670.0              19639981
# 2805       2805.0              20089283
# 3065       3065.0              21067896
# 3257       3257.0              21765818
# 3359       3359.0              22230184
# 3372       3372.0              22247072
# 3455       3455.0              22340146
# 3571       3571.0              23026367
# 3605       3605.0              23100799
# 4303       4303.0              25868032
# 5667       5667.0              31826983
# 6244       6244.0              33051319
# 11128     11127.0            47007658.0
# 11920     11919.0            49045093.0
# 12299     12298.0            50106680.0
# 12712     12711.0            50796337.0
# 12841     12840.0            50893960.0
# 12864     12863.0            51164390.0
# 13674     13673.0            52557368.0
# 13675     13674.0            52557770.0
# ...

# %%
Fd2.to_csv("Fd2.csv")
from google.colab import files 
files.download("Fd2.csv")

# %%
Fd3 = California.loc[California['property_type'] == "Private room"]
Fd3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count  latitude  \
# 7              7                  1.00                    2  37.71750
# 1575        1575                  1.00                    3  37.75145
# 2049        2049                  0.83                    7  37.79586
# 4014        4014                  0.83                    7  37.79525
#
#       longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# 7    -122.39698             2          0         1     1     95  ...
# 1575 -122.40719             2          0         1     0     69  ...
# 2049 -122.41915             2          0         0     1     60  ...
# 4014 -122.41931             1          0         0     1     56  ...
#
#         bathrooms_text  bedrooms.1  \
# 7     1.5 shared baths           1
# 1575     1 shared bath           1
# 2049    1 private bath           0
# 4014            1 bath           0
#
#                                               amenities  calendar_updated.1  \
# ...

# %%
Fd3.to_csv("Fd3.csv")
from google.colab import files 
files.download("Fd3.csv")

# %% [markdown]
# ### **e) Los registros que cuenten con bathroom > 1**

# %%
Fe1 = España.loc[España['bathrooms'] >= 1]
Fe1
# Out:
#                      Unnamed: 0                  id listing_url  \
# 1295  Passionate photographer.   within a few hours           f
#
#                                               scrape_id  \
# 1295  https://a0.muscache.com/im/users/34733512/prof...
#
#                                            last_scraped source  \
# 1295  https://a0.muscache.com/im/users/34733512/prof...      0
#
#                     name description picture_url                     host_id  \
# 1295  ['email', 'phone']           t           t  Sa Riera, Catalunya, Spain
#
#       ... review_scores_checkin review_scores_communication  \
# 1295  ...                   NaN                         NaN
#
#      review_scores_location review_scores_value  \
# 1295                    NaN                 NaN
#
#      calculated_host_listings_count  \
# 1295                            NaN
#
#      calculated_host_listings_count_entire_homes  \
# 1295                                         NaN
#
# ...

# %%
Fe1.to_csv("Fe1.csv")
from google.colab import files 
files.download("Fe1.csv")

# %%
Fe2 = DF.loc[DF['bathrooms'] >= 1]
Fe2
# Out:
#       Unnamed: 0              id listing_url  \
# 6779         NaN  within an hour           t
#
#                                               scrape_id  \
# 6779  https://a0.muscache.com/im/users/4274771/profi...
#
#                                            last_scraped    source  \
# 6779  https://a0.muscache.com/im/users/4274771/profi...  Coyoacán
#
#                     name description picture_url  \
# 6779  ['email', 'phone']           t           t
#
#                                     host_id  ... review_scores_checkin  \
# 6779  Mexico City, Ciudad de México, Mexico  ...                   NaN
#
#      review_scores_communication review_scores_location review_scores_value  \
# 6779                         NaN                    NaN                 NaN
#
#      calculated_host_listings_count  \
# 6779                            NaN
#
#      calculated_host_listings_count_entire_homes  \
# 6779                                         NaN
#
# ...

# %%
Fe2.to_csv("Fe2.csv")
from google.colab import files 
files.download("Fe2.csv")

# %%
Fe3 = California.loc[California['bathrooms'] >= 1]
Fe3
# Out:
# Empty DataFrame
# ...

# %%
Fe3.to_csv("Fe3.csv")
from google.colab import files 
files.download("Fe3.csv")

# %% [markdown]
# ### **f) Los registros cuyo precio sea mayor de $10,000 y que sean de tipo “Entire home”**

# %%
Ff1 = España.loc[(España['price'] >= 10000 ) | (España['property_type'] == "Entire home")]
Ff1
# Out:
#       Unnamed: 0                    id  \
# 9              9               1222762
# 10            10                753604
# 11            11                 48764
# 15            15                 93343
# 22            22               1234785
# ...          ...                   ...
# 19639      19638  858000000000000000.0
# 19641      19640  858000000000000000.0
# 19642      19641  858000000000000000.0
# 19650      19649  858000000000000000.0
# 19651      19650  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 9                 https://www.airbnb.com/rooms/1222762       2.02303E+13
# 10                 https://www.airbnb.com/rooms/753604       2.02303E+13
# 11                  https://www.airbnb.com/rooms/48764       2.02303E+13
# 15                  https://www.airbnb.com/rooms/93343       2.02303E+13
# 22                https://www.airbnb.com/rooms/1234785       2.02303E+13
# ...

# %%
Ff1.to_csv("Ff1.csv")
from google.colab import files 
files.download("Ff1.csv")

# %%
Ff2 = DF.loc[(DF['price'] >= 10000 ) | (DF['property_type'] == "Entire home")]
Ff2
# Out:
#        Unnamed: 0                    id  \
# 4             4.0                 44616
# 9             9.0                728372
# 27           27.0                165772
# 37           37.0                187030
# 48           48.0               2228415
# ...           ...                   ...
# 24154     24153.0  854000000000000000.0
# 24168     24167.0  856000000000000000.0
# 24186     24185.0  856000000000000000.0
# 24193     24192.0  856000000000000000.0
# 24207     24206.0  857000000000000000.0
#
#                                            listing_url         scrape_id  \
# 4                   https://www.airbnb.com/rooms/44616          2.02E+13
# 9                  https://www.airbnb.com/rooms/728372          2.02E+13
# 27                 https://www.airbnb.com/rooms/165772          2.02E+13
# 37                 https://www.airbnb.com/rooms/187030          2.02E+13
# 48                https://www.airbnb.com/rooms/2228415          2.02E+13
# ...

# %%
Ff2.to_csv("Ff2.csv")
from google.colab import files 
files.download("Ff2.csv")

# %%
Ff3 = California.loc[(California['price'] >= 10000 ) | (California['property_type'] == "Entire home")]
Ff3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 9              9                  0.84                    2  37.785460
# 21            21                  0.94                    2  37.741540
# 40            40                  1.00                    1  37.743250
# 47            47                  1.00                    1  37.734660
# 48            48                  1.00                    6  37.760800
# ...          ...                   ...                  ...        ...
# 6855        6855                  1.00                    1  37.718774
# 6865        6865                  1.00                    2  37.742326
# 6904        6904                  0.50                    1  37.736539
# 6905        6905                  1.00                    2  37.731587
# 6910        6910                  0.00                    1  37.745091
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Ff3.to_csv("Ff3.csv")
from google.colab import files 
files.download("Ff3.csv")

# %% [markdown]
# ### **g) Los registros cuyo review_scores_cleanliness > 4.5**

# %%
Fg1 = España.loc[España['review_scores_cleanliness'] >= 4.5]
Fg1
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 1              1               1205757
# 3              3                751638
# 4              4                 41342
# 5              5                751997
# ...          ...                   ...
# 18962      18961  833000000000000000.0
# 19002      19001  841000000000000000.0
# 19047      19046  842000000000000000.0
# 19078      19077  842000000000000000.0
# 19203      19202  843000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 1                 https://www.airbnb.com/rooms/1205757       2.02303E+13
# 3                  https://www.airbnb.com/rooms/751638       2.02303E+13
# 4                   https://www.airbnb.com/rooms/41342       2.02303E+13
# 5                  https://www.airbnb.com/rooms/751997       2.02303E+13
# ...

# %%
Fg1.to_csv("Fg1.csv")
from google.colab import files 
files.download("Fg1.csv")

# %%
Fg2 = DF.loc[DF['review_scores_cleanliness'] >= 4.5]
Fg2
# Out:
#        Unnamed: 0                    id  \
# 0             0.0               2056638
# 1             1.0               2072354
# 2             2.0                696037
# 4             4.0                 44616
# 5             5.0               2075738
# ...           ...                   ...
# 24058     24057.0  853000000000000000.0
# 24059     24058.0  853000000000000000.0
# 24110     24109.0  853000000000000000.0
# 24128     24127.0  853000000000000000.0
# 24189     24188.0  856000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                 https://www.airbnb.com/rooms/2056638          2.02E+13
# 1                 https://www.airbnb.com/rooms/2072354          2.02E+13
# 2                  https://www.airbnb.com/rooms/696037          2.02E+13
# 4                   https://www.airbnb.com/rooms/44616          2.02E+13
# 5                 https://www.airbnb.com/rooms/2075738          2.02E+13
# ...

# %%
Fg2.to_csv("Fg2.csv")
from google.colab import files 
files.download("Fg2.csv")

# %%
Fg3 = California.loc[California['review_scores_cleanliness'] >= 4.5]
Fg3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 0              0                  1.00                    1  37.770280
# 1              1                  0.71                    2  37.744740
# 3              3                  0.00                    2  37.775640
# 4              4                  0.90                    2  37.760300
# 5              5                  0.95                    1  37.784400
# ...          ...                   ...                  ...        ...
# 6924        6924                  0.96                    7  37.716079
# 6925        6925                  0.96                    7  37.716214
# 6926        6926                  0.96                    7  37.716070
# 6927        6927                  0.98                   32  37.788619
# 6932        6932                  0.00                    1  37.763060
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Fg3.to_csv("Fg3.csv")
from google.colab import files 
files.download("Fg3.csv")

# %% [markdown]
# ### **h) Los registros cuyo review_scores_value > 4.9**

# %%
Fh1 = España.loc[España['review_scores_value'] >= 4.9]
Fh1
# Out:
#       Unnamed: 0                    id  \
# 12            12                755927
# 22            22               1234785
# 26            26                774371
# 38            38               1247304
# 40            40               1250062
# ...          ...                   ...
# 19039      19038  841000000000000000.0
# 19047      19046  842000000000000000.0
# 19078      19077  842000000000000000.0
# 19203      19202  843000000000000000.0
# 19468      19467  850000000000000000.0
#
#                                            listing_url         scrape_id  \
# 12                 https://www.airbnb.com/rooms/755927       2.02303E+13
# 22                https://www.airbnb.com/rooms/1234785       2.02303E+13
# 26                 https://www.airbnb.com/rooms/774371       2.02303E+13
# 38                https://www.airbnb.com/rooms/1247304       2.02303E+13
# 40                https://www.airbnb.com/rooms/1250062       2.02303E+13
# ...

# %%
Fh1.to_csv("Fh1.csv")
from google.colab import files 
files.download("Fh1.csv")

# %%
Fh2 = DF.loc[DF['review_scores_value'] >= 4.9]
Fh2
# Out:
#        Unnamed: 0                    id  \
# 10           10.0               2083241
# 11           11.0                 67703
# 13           13.0                 70644
# 24           24.0                783080
# 26           26.0               2118573
# ...           ...                   ...
# 24058     24057.0  853000000000000000.0
# 24059     24058.0  853000000000000000.0
# 24110     24109.0  853000000000000000.0
# 24128     24127.0  853000000000000000.0
# 24189     24188.0  856000000000000000.0
#
#                                            listing_url         scrape_id  \
# 10                https://www.airbnb.com/rooms/2083241          2.02E+13
# 11                  https://www.airbnb.com/rooms/67703          2.02E+13
# 13                  https://www.airbnb.com/rooms/70644          2.02E+13
# 24                 https://www.airbnb.com/rooms/783080          2.02E+13
# 26                https://www.airbnb.com/rooms/2118573          2.02E+13
# ...

# %%
Fh2.to_csv("Fh2.csv")
from google.colab import files 
files.download("Fh2.csv")

# %%
Fh3 = California.loc[California['review_scores_value'] >= 4.9]
Fh3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 9              9                  0.84                    2  37.785460
# 24            24                  1.00                    2  37.762160
# 26            26                  1.00                    1  37.762370
# 38            38                  0.00                    1  37.751170
# 46            46                  1.00                    2  37.717270
# ...          ...                   ...                  ...        ...
# 6920        6920                  0.99                    9  37.801789
# 6924        6924                  0.96                    7  37.716079
# 6925        6925                  0.96                    7  37.716214
# 6927        6927                  0.98                   32  37.788619
# 6932        6932                  0.00                    1  37.763060
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Fh3.to_csv("Fh3.csv")
from google.colab import files 
files.download("Fh3.csv")

# %% [markdown]
# ### **i) Los registros cuya availability_365< 100**

# %%
Fi1 = España.loc[España['availability_365'] <= 100]
Fi1
# Out:
#       Unnamed: 0                    id  \
# 4              4                 41342
# 7              7               1215790
# 11            11                 48764
# 15            15                 93343
# 20            20               1234784
# ...          ...                   ...
# 19628      19627  858000000000000000.0
# 19633      19632  858000000000000000.0
# 19635      19634  858000000000000000.0
# 19639      19638  858000000000000000.0
# 19655      19654  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 4                   https://www.airbnb.com/rooms/41342       2.02303E+13
# 7                 https://www.airbnb.com/rooms/1215790       2.02303E+13
# 11                  https://www.airbnb.com/rooms/48764       2.02303E+13
# 15                  https://www.airbnb.com/rooms/93343       2.02303E+13
# 20                https://www.airbnb.com/rooms/1234784       2.02303E+13
# ...

# %%
Fi1.to_csv("Fi1.csv")
from google.colab import files 
files.download("Fi1.csv")

# %%
Fi2 = DF.loc[DF['availability_365'] <= 100]
Fi2
# Out:
#        Unnamed: 0                    id  \
# 2             2.0                696037
# 21           21.0                131610
# 26           26.0               2118573
# 37           37.0                187030
# 38           38.0                187745
# ...           ...                   ...
# 24160     24159.0  856000000000000000.0
# 24166     24165.0  857000000000000000.0
# 24171     24170.0  857000000000000000.0
# 24187     24186.0  856000000000000000.0
# 24194     24193.0  856000000000000000.0
#
#                                            listing_url         scrape_id  \
# 2                  https://www.airbnb.com/rooms/696037          2.02E+13
# 21                 https://www.airbnb.com/rooms/131610          2.02E+13
# 26                https://www.airbnb.com/rooms/2118573          2.02E+13
# 37                 https://www.airbnb.com/rooms/187030          2.02E+13
# 38                 https://www.airbnb.com/rooms/187745          2.02E+13
# ...

# %%
Fi2.to_csv("Fi2.csv")
from google.colab import files 
files.download("Fi2.csv")

# %%
Fi3 = California.loc[California['availability_365'] <= 100]
Fi3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 5              5                  0.95                    1  37.784400
# 8              8                  0.61                    2  37.771960
# 9              9                  0.84                    2  37.785460
# 11            11                  1.00                    9  37.792330
# 15            15                  0.80                    5  37.772520
# ...          ...                   ...                  ...        ...
# 6913        6913                  1.00                    2  37.719700
# 6917        6917                  1.00                    1  37.748247
# 6918        6918                  1.00                   23  37.767920
# 6923        6923                  1.00                    3  37.784690
# 6931        6931                  1.00                    9  37.791994
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Fi3.to_csv("Fi3.csv")
from google.colab import files 
files.download("Fi3.csv")

# %% [markdown]
# ### **j) Los registros cuya host_response_time sea “within an hour”**

# %%
Fj1 = España.loc[España['host_response_time'] == "within an hour"]
Fj1
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 5              5                751997
# 6              6                752035
# 8              8                 45400
# 10            10                753604
# ...          ...                   ...
# 19648      19647  858000000000000000.0
# 19649      19648  858000000000000000.0
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19654      19653  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551       2.02303E+13
# 5                  https://www.airbnb.com/rooms/751997       2.02303E+13
# 6                  https://www.airbnb.com/rooms/752035       2.02303E+13
# 8                   https://www.airbnb.com/rooms/45400       2.02303E+13
# 10                 https://www.airbnb.com/rooms/753604       2.02303E+13
# ...

# %%
Fj1.to_csv("Fj1.csv")
from google.colab import files 
files.download("Fj1.csv")

# %%
Fj2 = DF.loc[DF['host_response_time'] == "within an hour"]
Fj2
# Out:
#        Unnamed: 0                    id  \
# 2             2.0                696037
# 4             4.0                 44616
# 6             6.0                 56074
# 7             7.0                 61792
# 8             8.0                704779
# ...           ...                   ...
# 24215     24214.0  854000000000000000.0
# 24217     24216.0  854000000000000000.0
# 24218     24217.0  854000000000000000.0
# 24220     24219.0  854000000000000000.0
# 24223     24222.0  854000000000000000.0
#
#                                            listing_url         scrape_id  \
# 2                  https://www.airbnb.com/rooms/696037          2.02E+13
# 4                   https://www.airbnb.com/rooms/44616          2.02E+13
# 6                   https://www.airbnb.com/rooms/56074          2.02E+13
# 7                   https://www.airbnb.com/rooms/61792          2.02E+13
# 8                  https://www.airbnb.com/rooms/704779          2.02E+13
# ...

# %%
Fj2.to_csv("Fj2.csv")
from google.colab import files 
files.download("Fj2.csv")

# %%
Fj3 = California.loc[California['host_response_time'] == "within an hour"]
Fj3
# Out:
#       Unnamed: 0  host_acceptance_rate  host_listings_count   latitude  \
# 0              0                  1.00                    1  37.770280
# 2              2                  0.73                   13  37.765550
# 4              4                  0.90                    2  37.760300
# 5              5                  0.95                    1  37.784400
# 12            12                  0.82                    2  37.728330
# ...          ...                   ...                  ...        ...
# 6929        6929                  0.97                   67  37.725231
# 6930        6930                  1.00                    6  37.753771
# 6931        6931                  1.00                    9  37.791994
# 6934        6934                  0.50                    3  37.738325
# 6935        6935                  0.00                    2  37.786442
#
#        longitude  accommodates  bathrooms  bedrooms  beds  price  ...  \
# ...

# %%
Fj3.to_csv("Fj3.csv")
from google.colab import files 
files.download("Fj3.csv")
